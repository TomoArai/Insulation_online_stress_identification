# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
import pandas as pd

# %%
dataset_train=pd.read_excel('oil.xlsx') #excle データをインポート

# %%
dataset_train
# Out:
#      t h  Req MΩ  Ceq pF   DFeq  Req pu  Ceq pu  Dfeq pu ANN output
# 0     24   295.2   287.8   1.88   1.067    1.10     1.03       good
# 1     48   256.5   290.8   2.03   0.927    1.11     1.11       good
# 2     84   238.6   293.7   2.07   0.863    1.12     1.13       good
# 3    120   217.4   297.7   2.11   0.786    1.13     1.16       good
# 4    156   195.6   304.3   2.11   0.707    1.16     1.15       good
# 5    192   192.5   303.5   2.17   0.696    1.16     1.19       good
# 6    228   183.7   302.9   2.30   0.664    1.15     1.26       good
# 7    264   184.0   307.1   2.15   0.665    1.17     1.18       good
# 8    300    38.2   300.5   3.95   0.138    1.14     2.16        oil
# 9    336    23.7   306.9   3.97   0.086    1.17     2.17        oil
# 10   372    18.6   354.8   4.01   0.067    1.35     2.20        oil
# 11   396    17.8   351.4   4.22   0.065    1.34     2.31        oil
# 12   444    15.8   412.9   4.06   0.057    1.57     2.22        oil
# 13   456    15.5   406.5   4.22   0.056    1.55     2.31        oil
# 14   516    12.9   403.1   5.09   0.047    1.54     2.79        oil
# 15   588    11.5   463.1   4.98   0.041    1.76     2.73        oil
# 16   660    10.8   487.2   5.04   0.039    1.86     2.76        oil
# 17   756     9.5   500.0   5.59   0.034    1.90     3.06        oil
# 18   852     8.8   521.6   5.81   0.032    1.99     3.18        oil
# 19   960     7.8   538.5   6.33   0.028    2.05     3.46        oil
# 20  1068     6.5   588.6   6.95   0.023    2.24     3.80        oil
# 21  1176     5.3   626.5   8.05   0.019    2.39     4.41        oil
# 22  1260     5.0   636.0   8.40   0.018    2.42     4.60        oil
# 23  1356     4.4   636.6   9.38   0.016    2.43     5.13        oil
# 24  1464     4.0   590.2  11.12   0.015    2.25     6.08        oil
# 25  1560     3.4   593.0  13.33   0.012    2.26     7.29        oil
# 26  1608     3.2   593.4  13.82   0.012    2.26     7.56        oil
# 27  1656     3.0   633.7  13.99   0.011    2.41     7.65        oil
# 28  1680     2.8   619.3  15.04   0.010    2.36     8.23        oil

# %%
# import some data to play with
X = dataset_train.drop(['t h','Req MΩ','Ceq pF','DFeq','ANN output'],axis=1) 
y = dataset_train['t h']

# %%
X
# Out:
#     Req pu  Ceq pu  Dfeq pu
# 0    1.067    1.10     1.03
# 1    0.927    1.11     1.11
# 2    0.863    1.12     1.13
# 3    0.786    1.13     1.16
# 4    0.707    1.16     1.15
# 5    0.696    1.16     1.19
# 6    0.664    1.15     1.26
# 7    0.665    1.17     1.18
# 8    0.138    1.14     2.16
# 9    0.086    1.17     2.17
# 10   0.067    1.35     2.20
# 11   0.065    1.34     2.31
# 12   0.057    1.57     2.22
# 13   0.056    1.55     2.31
# 14   0.047    1.54     2.79
# 15   0.041    1.76     2.73
# 16   0.039    1.86     2.76
# 17   0.034    1.90     3.06
# 18   0.032    1.99     3.18
# 19   0.028    2.05     3.46
# 20   0.023    2.24     3.80
# 21   0.019    2.39     4.41
# 22   0.018    2.42     4.60
# 23   0.016    2.43     5.13
# 24   0.015    2.25     6.08
# 25   0.012    2.26     7.29
# 26   0.012    2.26     7.56
# 27   0.011    2.41     7.65
# 28   0.010    2.36     8.23

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

model_lr = LinearRegression()
model_lr.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(model_lr.coef_)
print(model_lr.intercept_)
print(model_lr.score(X, y))
# Out:
# [ -4.03422596 480.48826497 143.75388635]
# -579.2904634734967
# 0.9922547073585097

# %%
predict_result = model_lr.predict(X)

# %%
predict_result
# Out:
# array([  93.00861184,  109.87859703,  117.81674787,  127.24488251,
#         140.54069545,  146.33522739,  151.72221201,  149.82763218,
#         278.41782993,  294.47979649,  385.35695107,  396.37306437,
#         493.97978935,  497.31190805,  561.54519888,  658.65158935,
#         711.02110089,  773.38696853,  833.88944719,  902.98596817,
#        1043.175231  , 1202.95447833, 1244.68639891, 1325.68890977,
#        1375.77124834, 1554.53043615, 1593.34398547, 1678.35910921,
#        1737.71598427])

# %%
result = pd.DataFrame(y)
result['lr'] = predict_result
col_names = ['Experimental time data(t h)','Prediction time data']
result.columns=col_names
result
# Out:
#     Experimental time data(t h)  Prediction time data
# 0                            24             93.008612
# 1                            48            109.878597
# 2                            84            117.816748
# 3                           120            127.244883
# 4                           156            140.540695
# 5                           192            146.335227
# 6                           228            151.722212
# 7                           264            149.827632
# 8                           300            278.417830
# 9                           336            294.479796
# 10                          372            385.356951
# 11                          396            396.373064
# 12                          444            493.979789
# 13                          456            497.311908
# 14                          516            561.545199
# 15                          588            658.651589
# 16                          660            711.021101
# 17                          756            773.386969
# 18                          852            833.889447
# 19                          960            902.985968
# 20                         1068           1043.175231
# 21                         1176           1202.954478
# 22                         1260           1244.686399
# 23                         1356           1325.688910
# 24                         1464           1375.771248
# 25                         1560           1554.530436
# 26                         1608           1593.343985
# 27                         1656           1678.359109
# 28                         1680           1737.715984

# %%
import seaborn as sns

sns.lmplot(x="Experimental time data(t h)",y="Prediction time data",data=result,fit_reg=False)

# %%
import seaborn as sns

sns.lmplot(x="Req pu",y="t h",data=dataset_train,fit_reg=False)

# %%
sns.lmplot(x="Ceq pu",y="t h",data=dataset_train,fit_reg=False)

# %%
sns.lmplot(x="Dfeq pu",y="t h",data=dataset_train,fit_reg=False)

# %%
model_lr.coef_
# Out:
# array([ -4.03422596, 480.48826497, 143.75388635])

# %%
print('切片の値は{}'.format(model_lr.intercept_))
# Out:
# 切片の値は-579.2904634734967
