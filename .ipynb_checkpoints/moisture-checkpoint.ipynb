# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
import pandas as pd

# %%
dataset_train=pd.read_excel('moisture.xlsx') #excle データをインポート

# %%
dataset_train
# Out:
#     t h  Req MΩ  Ceq pF  DFeq  Req pu  Ceq pu  Dfeq pu ANN output
# 0    12   335.4    19.5  0.41   0.950    1.12     0.94       good
# 1    18   341.8    21.4  0.36   0.970    1.23     0.83       good
# 2    24   359.4    19.8  0.37   1.020    1.14     0.86       good
# 3    30   331.0    20.7  0.39   0.940    1.19     0.89       good
# 4    36   345.6    21.3  0.36   0.980    1.23     0.83       good
# 5    42   325.7    21.5  0.38   0.930    1.24     0.87       good
# 6    48   360.3    19.3  0.38   1.020    1.11     0.88       good
# 7    54   304.1    18.7  0.47   0.865    1.08     1.07       good
# 8    60    96.0    29.3  0.94   0.273    1.69     2.17   moisture
# 9    62    82.1    33.3  0.97   0.233    1.92     2.23   moisture
# 10   64    63.5    41.4  1.01   0.181    2.39     2.32   moisture
# 11   66    27.4    93.2  1.04   0.078    5.37     2.39   moisture
# 12   68    17.6   132.4  1.13   0.050    7.63     2.61   moisture
# 13   70    11.8   186.5  1.20   0.034   10.77     2.79   moisture
# 14   71    11.7   189.4  1.20   0.033   10.92     2.75   moisture
# 15   72     9.4   229.3  1.23   0.027   13.22     2.83   moisture
# 16   73     7.3   292.1  1.24   0.021   16.84     2.85   moisture
# 17   74     6.7   319.8  1.25   0.019   18.43     2.87   moisture
# 18   75     5.4   389.2  1.27   0.015   22.43     2.92   moisture
# 19   76     4.1   504.8  1.29   0.012   29.09     2.96   moisture
# 20   77     3.6   571.8  1.29   0.010   32.96     2.97   moisture
# 21   78     3.4   596.1  1.32   0.010   34.36     3.03   moisture
# 22   79     2.0  1009.0  1.32   0.006   58.20     3.04   moisture
# 23   80     1.7  1203.0  1.33   0.005   69.37     3.06   moisture
# 24   81     1.5  1316.0  1.34   0.004   75.86     3.07   moisture
# 25   82     1.2  1630.0  1.34   0.004   93.98     3.08   moisture
# 26   83     1.1  1837.0  1.35   0.003  105.92     3.10   moisture
# 27   84     0.9  2154.8  1.36   0.003  124.20     3.12   moisture
# 28   85     0.6  3107.0  1.36   0.002  179.13     3.13   moisture
# 29   86     0.3  4551.0  1.76   0.001  262.32     4.10   moisture

# %%
# import some data to play with
X = dataset_train.drop(['t h','Req MΩ','Ceq pF','DFeq','ANN output'],axis=1) 
y = dataset_train['t h']

# %%
X
# Out:
#     Req pu  Ceq pu  Dfeq pu
# 0    0.950    1.12     0.94
# 1    0.970    1.23     0.83
# 2    1.020    1.14     0.86
# 3    0.940    1.19     0.89
# 4    0.980    1.23     0.83
# 5    0.930    1.24     0.87
# 6    1.020    1.11     0.88
# 7    0.865    1.08     1.07
# 8    0.273    1.69     2.17
# 9    0.233    1.92     2.23
# 10   0.181    2.39     2.32
# 11   0.078    5.37     2.39
# 12   0.050    7.63     2.61
# 13   0.034   10.77     2.79
# 14   0.033   10.92     2.75
# 15   0.027   13.22     2.83
# 16   0.021   16.84     2.85
# 17   0.019   18.43     2.87
# 18   0.015   22.43     2.92
# 19   0.012   29.09     2.96
# 20   0.010   32.96     2.97
# 21   0.010   34.36     3.03
# 22   0.006   58.20     3.04
# 23   0.005   69.37     3.06
# 24   0.004   75.86     3.07
# 25   0.004   93.98     3.08
# 26   0.003  105.92     3.10
# 27   0.003  124.20     3.12
# 28   0.002  179.13     3.13
# 29   0.001  262.32     4.10

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

model_lr = LinearRegression()
model_lr.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(model_lr.coef_)
print(model_lr.intercept_)
print(model_lr.score(X, y))
# Out:
# [-36.75511716   0.0558307    2.92215606]
# 65.24370797938413
# 0.8826637869175002

# %%
predict_result = model_lr.predict(X)

# %%
predict_result
# Out:
# array([33.13570376, 32.08530563, 30.33018969, 33.36105528, 31.71775446,
#        33.67295486, 30.38695789, 36.63753578, 61.64499352, 63.30336863,
#        65.5038692 , 69.66057268, 71.45876768, 72.74814604, 72.67638952,
#        73.25910332, 73.74018428, 73.96090845, 74.47735952, 75.07634358,
#        75.39514019, 75.64863253, 77.15587847, 77.87470563, 78.30302355,
#        79.34389741, 80.10571421, 81.18474254, 84.3174996 , 91.83330208])

# %%
result = pd.DataFrame(y)
result['lr'] = predict_result
col_names = ['Experimental time data(t h)','Prediction time data']
result.columns=col_names
result
# Out:
#     Experimental time data(t h)  Prediction time data
# 0                            12             33.135704
# 1                            18             32.085306
# 2                            24             30.330190
# 3                            30             33.361055
# 4                            36             31.717754
# 5                            42             33.672955
# 6                            48             30.386958
# 7                            54             36.637536
# 8                            60             61.644994
# 9                            62             63.303369
# 10                           64             65.503869
# 11                           66             69.660573
# 12                           68             71.458768
# 13                           70             72.748146
# 14                           71             72.676390
# 15                           72             73.259103
# 16                           73             73.740184
# 17                           74             73.960908
# 18                           75             74.477360
# 19                           76             75.076344
# 20                           77             75.395140
# 21                           78             75.648633
# 22                           79             77.155878
# 23                           80             77.874706
# 24                           81             78.303024
# 25                           82             79.343897
# 26                           83             80.105714
# 27                           84             81.184743
# 28                           85             84.317500
# 29                           86             91.833302

# %%
import seaborn as sns
sns.set_context(context=None, font_scale=20, rc=None)

sns.regplot(x="Experimental time data(t h)",y="Prediction time data",data=result, ci = 0, order = 2)

# %%
import seaborn as sns

sns.regplot(x="t h", y="Req pu",data=dataset_train, ci = 0, order = 2)

# %%
sns.regplot(x="t h", y="Ceq pu",data=dataset_train, ci = 0, order = 2)

# %%
sns.regplot(x="t h", y="Dfeq pu",data=dataset_train, ci = 0, order = 2)

# %%
model_lr.coef_
# Out:
# array([-36.75511716,   0.0558307 ,   2.92215606])

# %%
print('切片の値は{}'.format(model_lr.intercept_))
# Out:
# 切片の値は65.24370797938413
